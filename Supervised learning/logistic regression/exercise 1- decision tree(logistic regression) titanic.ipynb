# %%
import pandas as pd
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis = 'columns',inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e94ad420bd53> in <module>
# ----> 1 df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis = 'columns',inplace = True)
#
# c:\users\nihal khan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# c:\users\nihal khan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
df
# Out:
#      Survived  Pclass     Sex   Age Cabin
# 0           0       3    male  22.0   NaN
# 1           1       1  female  38.0   C85
# 2           1       3  female  26.0   NaN
# 3           1       1  female  35.0  C123
# 4           0       3    male  35.0   NaN
# ..        ...     ...     ...   ...   ...
# 886         0       2    male  27.0   NaN
# 887         1       1  female  19.0   B42
# 888         0       3  female   NaN   NaN
# 889         1       1    male  26.0  C148
# 890         0       3    male  32.0   NaN
#
# [891 rows x 5 columns]

# %%
df.drop('Cabin')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-4fdde87c811c> in <module>
# ----> 1 df.drop('Cabin')
#
# c:\users\nihal khan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# c:\users\nihal khan\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
inputs = df.drop('Survived',axis = 'columns')
target  = df.Survived

# %%
inputs
# Out:
#      Pclass     Sex   Age Cabin
# 0         3    male  22.0   NaN
# 1         1  female  38.0   C85
# 2         3  female  26.0   NaN
# 3         1  female  35.0  C123
# 4         3    male  35.0   NaN
# ..      ...     ...   ...   ...
# 886       2    male  27.0   NaN
# 887       1  female  19.0   B42
# 888       3  female   NaN   NaN
# 889       1    male  26.0  C148
# 890       3    male  32.0   NaN
#
# [891 rows x 4 columns]

# %%
dummy  = inputs.drop('Cabin',axis = 'columns')
dummy
# Out:
#      Pclass     Sex   Age
# 0         3    male  22.0
# 1         1  female  38.0
# 2         3  female  26.0
# 3         1  female  35.0
# 4         3    male  35.0
# ..      ...     ...   ...
# 886       2    male  27.0
# 887       1  female  19.0
# 888       3  female   NaN
# 889       1    male  26.0
# 890       3    male  32.0
#
# [891 rows x 3 columns]

# %%
dummy.Sex = dummy.Sex.map({'male':1,'female':2})
dummy
# Out:
#      Pclass  Sex   Age
# 0         3    1  22.0
# 1         1    2  38.0
# 2         3    2  26.0
# 3         1    2  35.0
# 4         3    1  35.0
# ..      ...  ...   ...
# 886       2    1  27.0
# 887       1    2  19.0
# 888       3    2   NaN
# 889       1    1  26.0
# 890       3    1  32.0
#
# [891 rows x 3 columns]

# %%
dummy.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
dummy.Age = dummy.Age.fillna(dummy.Age.mean())
dummy.Age
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
dummy
# Out:
#      Pclass  Sex        Age
# 0         3    1  22.000000
# 1         1    2  38.000000
# 2         3    2  26.000000
# 3         1    2  35.000000
# 4         3    1  35.000000
# ..      ...  ...        ...
# 886       2    1  27.000000
# 887       1    2  19.000000
# 888       3    2  29.699118
# 889       1    1  26.000000
# 890       3    1  32.000000
#
# [891 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dummy,target,test_size=0.2)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
model.score(X_test,y_test)
# Out:
# 0.8379888268156425

# %%
X_test
# Out:
#      Pclass  Sex        Age
# 270       1    1  29.699118
# 848       2    1  28.000000
# 794       3    1  25.000000
# 732       2    1  29.699118
# 823       3    2  27.000000
# ..      ...  ...        ...
# 412       1    2  33.000000
# 887       1    2  19.000000
# 387       2    2  36.000000
# 92        1    1  46.000000
# 336       1    1  29.000000
#
# [179 rows x 3 columns]

# %%
model.predict([[1,1,29.699118]])
# Out:
# array([0], dtype=int64)
